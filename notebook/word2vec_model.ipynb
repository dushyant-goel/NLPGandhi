# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import nltk
# nltk.download('all')

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import WordNetLemmatizer

# %%
# corpus_files = [f"../corpus/mahatma-gandhi-collected-works-volume-{i}.txt" for i in range(1, 99)]
corpus_files = [f"../Vol.1: 1884 - 30 NOVEMBER, 1896/page_{i}.txt" for i in range(1,476)]
print(f'Found {len(corpus_files)} files in the corpus directory.')

documents = []

for file_path in corpus_files:
    # print(f'Loading file: {file_path}')
    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()
        documents.append(text)

print(f'Loaded {len(documents)} documents from {len(corpus_files)} files.')
# Out:
# Found 475 files in the corpus directory.
# Loaded 475 documents from 475 files.

# %%
documents

# %%
import string

translator = str.maketrans('', '', string.punctuation)
i = 0

# Function to preprocess text
def preprocess_text(text, idx):

    stop_words = set(stopwords.words("english"))

    # tokenize the text
    tokens = word_tokenize(text)

    # remove punctuation and convert to lowercase
    tokens = [s.translate(translator) for s in tokens]
    tokens = [word.lower() for word in tokens]
    
    # remove non-alphabetic strings (dates, numbers, etc.)
    tokens = [word for word in tokens if word.isalpha()]
    
    # remove stop words
    tokens = [word for word in tokens if word not in stop_words]

    # lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
    # remove small character tokens 
    tokens = [word for word in tokens if len(word) > 2]

    preprocessed_text = " ".join(tokens)
    return preprocessed_text

# preprocess the documents
preprocessed_documents = [preprocess_text(doc, idx) for idx, doc in enumerate(documents)]

# %%
for i, page in enumerate(preprocessed_documents, start=1):
    with open(f'../Vol.1: 1884 - 30 NOVEMBER, 1896/processed/page_{i}.txt', 'w', encoding='utf-8') as out:
        out.write(page)

# %% [markdown]
# Tokenize = check if stopwords are really removed. What remains?

# %%
# Uncomment to check if the preprocessing works correctly

# import string

# flat_token_list = []
# stop_words = set(stopwords.words("english"))

# # Collect all tokens into a flat list
# for doc in documents:
#     tokens = word_tokenize(doc)
    
#     translator = str.maketrans('', '', string.punctuation)
#     tokens = [s.translate(translator) for s in tokens]
#     tokens = [word.lower() for word in tokens]
#     tokens = [word for word in tokens if word.isalpha()]
    
#     tokens = [word for word in tokens if word not in stop_words]
#     flat_token_list.extend(tokens)

# %%
# Uncomment for verification

with open('tokens.txt', 'w') as f:
    for document in preprocessed_documents:
        f.write(f"{document}\n")

# %%
# Divide the preprocessed documents into phases
# Phase 1: 1-15
# 
# Phase 2 : 15-62
# Phase 3: 62-99

# Dictionary to hold the phase numbers and corresponding documents  
# index = doucment_number - 1
phase_dict = {
    "phase 1": [preprocessed_documents[i] for i in range(1-1, 15-1)],   # 1884 - 20 MAY, 1915
    "phase 2": [preprocessed_documents[i] for i in range(15-1, 62-1)],  # 21 MAY, 1915 - 7 OCTOBER, 1933
    "phase 3": [preprocessed_documents[i] for i in range(62-1, 99-1)]   # 8 OCTOBER, 1933 - 30 JANUARY, 1948
}

# %%
tokenized_docs = [doc.split() for doc in preprocessed_documents]
word2vec_model = Word2Vec(sentences=tokenized_docs, vector_size=100, window=5, min_count=1, sg=1, seed=43, workers=1)
model_path = f"../model/word2vec_model_vol1.model"
word2vec_model.save(model_path)

# %% [markdown]
# Final Model Training

# %%
# Train a word2vec model
from gensim.models import Word2Vec

# Train models by phase
for phase, docs in phase_dict.items():
    print(f"Training Word2Vec model for {phase}...")
    
    # Tokenize the preprocessed documents
    tokenized_docs = [doc.split() for doc in docs]
    
    # Create the Word2Vec model using skip-gram model
    # seed=43, workers=1 for reproducibility
    word2vec_model = Word2Vec(sentences=tokenized_docs, vector_size=100, window=5, min_count=1, sg=1, seed=43, workers=1)
    
    print(f"Model for {phase} trained.")

    # Save the model
    # model_path = f"../model/word2vec_model_{phase.replace(' ', '_')}.model"
    # word2vec_model.save(model_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       2 from gensim.models import Word2Vec
#       4 # Train models by phase
# ----> 5 for phase, docs in phase_dict.items():
#       6     print(f"Training Word2Vec model for {phase}...")
#       8     # Tokenize the preprocessed documents
#
# NameError: name 'phase_dict' is not defined

# %%
# Save the model (just in case)
# word2vec_model.save("../model/word2vec.model")
# Out:
# Training Word2Vec model for phase_1...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 50
#      47 # Tokenize the preprocessed documents
#      48 tokenized_docs = [doc.split() for doc in docs]
# ---> 50 model = train_model(
#      51     tokenized_docs,
#      52     vector_size=setting['vector_size'],
#      53     window=setting['window'],
#      54     min_count=setting['min_count'],
#      55     epochs=setting['epochs'],
#      56     seed=42
#      57 )
#      59 # Save the model (in - memory)
#      60 model_dict[phase] = model
#
# Cell In[10], line 16, in train_model(tokenized_docs, vector_size, window, min_count, epochs, seed)
#      14 def train_model(tokenized_docs, vector_size, window, min_count, epochs, seed):
# ---> 16     model = Word2Vec(
#      17         sentences=tokenized_docs,
# ...
