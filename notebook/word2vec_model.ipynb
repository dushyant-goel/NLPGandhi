# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package english_wordnet to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package english_wordnet is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /Users/dushyantgoel/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import WordNetLemmatizer

# %%
import glob


corpus_files = glob.glob("../data/corpus_txt/mahatma-gandhi-collected-works-volume-*.txt")
print(f'Found {len(corpus_files)} files in the corpus directory.')
documents = []

for file_path in corpus_files:
    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read()
        documents.append(text)

print(f'Loaded {len(documents)} documents from {len(corpus_files)} files.')
# Out:
# Found 98 files in the corpus directory.
# Loaded 98 documents from 98 files.

# %%
# create preprocess_text function
def preprocess_text(text):
    
    # tokenize the text
    tokens = word_tokenize(text)

    # remove stop words
    stop_words = set(stopwords.words("english"))
    tokens = [word for word in tokens if word.lower() not in stop_words]

    # lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    # join the tokens back into a single string
    preprocessed_text = " ".join(tokens)

    return preprocessed_text

# preprocess the documents
preprocessed_documents = [preprocess_text(doc) for doc in documents]

# %%
print(preprocessed_documents[0:2])  # show the first two preprocessed documents
# Out:
# ["1 . LETTER PADMAJA NAIDU September 5 , 1932 DEAR PADMAJA , basket orange ! Seeing insist sending matter say . let tell really good variety—very juicy . responded gentle driving poor little slave-driver . Even could decipher letter without difficulty . want , please , exert lying flat back . abomination . Even abomination loved one preferable silence . really ill , get willing assistance ? Anybody gladly write dictation . mention magnificent story Buddha brings mind many sacred thing . Yes , dream many dream . may airy nothing would crushed weight love appropriate people sort conditions—men , woman , boy girls.1 Sardar Mahadev book cope . former absorbed like diligent student Sanskrit study ; latter French Urdu thanks behalf offer . use , fear , wanting see . wish possible . Love u . , LAVE-DRIVER HRIMATI P ADMAJA NAIDU C/ ERVANTS INDIA OCIETY P OONA C ITY origin al : Padmaj Naidu Papers . Courte sy : Nehru Memori al Museum Librar 1 paragraph already reproduced “ Letter Padmaja Naidu ” , 5-9-1932 . VOL . 57 : 5 SEPTEMBER , 1932 - 15 NOVEMBER , 1932 1 2 . LETTER NANALAL K. JASANI September 5 , 1932 BHAI NANALAL , awaiting letter relieved came . already written Mayashankar1 ; hope got letter . restraining Champa . also dissuaded Manjula2 . think Maganlal would welcome . seems wise girl . find difficulty selling emerald ? obstruction somebody able sell ? certainly worthy wish withdraw money deposited name Doctor . daughter , however , get money set apart , present see possibility able withdraw part . Hence , time yet come thinking share . Everything settled train get rail . see provided family break bitterness disappears . Please write regularly . act Chhaganlal advises , everything end well . know go duty irrespective whether love slight , therefore , worry . Blessings BAPU Gujarati : C.W . 9470a 3 . LETTER September 5 , 1932 either cunning foolish . really know ‘ vikar ’ mean ? vikar resulting eating pulse resulting physical touch , sign something wrong u . disturb equilibrium . first kind vikar result swallowing external substance ; second change mental state resulting sight external object . vikar shake one ’ whole may prove harmful . woman feel vikar 1 2 2 Mayashankar Vrajlal Desai , business partner Dr. Pranjivan Mehta . Wife Maganlal Mehta . COLLECTED WORKS MAHATMA GANDHI towards man , society always hold guilty ; , spring desire marry person marriage forbidden , matter kept secret one ’ people one free marry . According , yet fit marry , studying still minor . relation . . . 1 improper , teacher , moreover , like brother . Call feeling like , whether vikar desire marriage , kept secret , therefore , blameworthy . understand meaning independence also . show letter elder free , lose independence seek safety . somebody post door-step , like Government bailiff depriving u freedom ; station watchman gate , lose freedom protect . way , adolescent state regard elder guardian interest , open heart show letter . lose independence seek protection . earnestly wish become independent . protecting independence advised show letter , etc. , parent . , however , reconcile feel irksome restraint , may keep letter private . want put pressure way , would crush individuality . wish become brave girl spirited servant people . shall extremely pained stop writing . [ Gujarati ] Mahadevbhaini Diary , Vol . II , pp . 6-7 4 . LETTER BEGUM MOHAMMAD ALAM [ September 6 , 1932 ] 2 conviction husband 3 come round . recieved doctor ’ letter kept informed health . letter given information regarding health . 1 2 3 name omitted source . report source dated September 6 . Dr. Mohammad Alam , prisoner Lahore Central Jail ailing . VOL . 57 : 5 SEPTEMBER , 1932 - 15 NOVEMBER , 1932 3 Please keep unbroken correspondence convey Sardar Patel ’ , Mahadev Desai ’ good wish doctor . grace God well , hope find difficulty reading letter written broken Urdu . Advance , 7-9-1932 . 5 . LETTER MOHAN N. PARIKH September 7 , 1932 CHI . MOHAN , May live long . good serve cou ...

# %%
# Divide the preprocessed documents into phases
# Phase 1: 1-15
# Phase 2 : 15-62
# Phase 3: 62-99

# Dictionary to hold the phase numbers and corresponding documents  
phase_dict = {
    "phase_1": [documents[i] for i in range(0, 15)],
    "phase_2": [documents[i] for i in range(15, 62)],
    "phase_3": [documents[i] for i in range(62, 98)]
}

# %% [markdown]
# Final Model Training

# %%
# Train a word2vec model
from gensim.models import Word2Vec

# Train models by phase
for phase, docs in phase_dict.items():
    print(f"Training Word2Vec model for {phase}...")
    
    # Tokenize the preprocessed documents
    tokenized_docs = [doc.split() for doc in docs]
    
    # Create the Word2Vec model using skip-gram model
    word2vec_model = Word2Vec(sentences=tokenized_docs, vector_size=100, window=5, min_count=1, sg=1)
    
    print(f"Model for {phase} trained.")

    # Save the model
    model_path = f"../model/word2vec_model_{phase}.model"
    word2vec_model.save(model_path)

    print(f"Model for {phase} saved to {model_path}.")
# Out:
# Training Word2Vec model for phase_1...
# Model for phase_1 trained.
# Training Word2Vec model for phase_2...
# Model for phase_2 trained.
# Training Word2Vec model for phase_3...
# Model for phase_3 trained.

# %% [markdown]
# Hyperparameter tuning - to get stable embeddings.

# %%
# from gensim.models import Word2Vec
# import numpy as np
# from collections import defaultdict 

# # Hyperparameters
# # vector_size : Larger sizes can capture more nuanced patterns but may introduce more noise / instability on small data
# # window: Smaller windows (2–5) capture syntactic/contextual similarity, larger windows (5–10) capture topical similarity
# # min_count: Removes rare words, improving model reliability but reducing vocabulary — higher values often improve stability
# # epochs (epochs or iter): More passes over the corpus increase stability and convergence
# # negative: Number of negative samples — increasing improves model robustness on sparse data
# # seed: Random seed affects initial weight assignment — important for testing stability across runs
# # workers: Not affecting stability, just speed (but can introduce non-determinism in multi-threaded training if seed is not fixed)

# def train_model(tokenized_docs, vector_size, window, min_count, epochs, seed):
    
#     model = Word2Vec(
#         sentences=tokenized_docs,
#         vector_size=vector_size, # embedding size
#         window=window, # context window size
#         min_count=min_count, # rare words
#         epochs=epochs, # training epochs
#         sg=1, # skip-gram
#         negative=5,
#         seed=seed, # for deterministic training
#         workers=1  # for deterministic training
#     )
#     return model

# word = "swaraj"
# top_n = 10

# hyperparameters = []
# # Enumerate over vector sizes
# for vector_size in range(150, 500, 50):
#     hyperparameters.append({
#         'vector_size': vector_size,
#         'window': 5,
#         'min_count': 2,
#         'epochs': 10
#     })

# for i, setting in enumerate(hyperparameters):
#     model_dict = {}
#     for phase, docs in phase_dict.items():
    
#         print(f"Training Word2Vec model for {phase}...")
#         # Tokenize the preprocessed documents
#         tokenized_docs = [doc.split() for doc in docs]
    
#         model = train_model(
#             tokenized_docs,
#             vector_size=setting['vector_size'],
#             window=setting['window'],
#             min_count=setting['min_count'],
#             epochs=setting['epochs'],
#             seed=42
#         )

#         # Save the model (in - memory)
#         model_dict[phase] = model
    
#     # Now load the models and find the jaccard similarity
    
#     neighbors = defaultdict(dict)
#     jaccard_results = defaultdict(dict)

#     phases = ["phase_1", "phase_2", "phase_3"]
    
#     for i in range(len(phases) - 1):
        
#         p1, p2 = phases[i], phases[i + 1]
#         set1, set2 = neighbors[word].get(p1, set()), neighbors[word].get(p2, set())
        
#         if set1 and set2:
#             intersection = len(set1 & set2)
#             union = len(set1 | set2)

#             jaccard_sim = intersection / union
#             jaccard_results[word][f"{p1}_vs_{p2}"] = jaccard_sim
#         else:
#             jaccard_results[word][f"{p1}_vs_{p2}"] = None

#     # Print results
#     print(f"\nJaccard Similarity Results for '{setting}':")
#     for word, results in jaccard_results.items():
#         print(f"\nKeyword: '{word}'")
#         for pair, score in results.items():
#             print(f"{pair}: {score:.3f}" if score is not None else f"{pair}: N/A")

    
#     # if keyword in model.wv:
#     #     neighbors = model.wv.most_similar(keyword, topn=top_n)
#     #     print(f"\nRun {i+1} | Settings: {setting}")
#     #     for word, sim in neighbors:
#     #         print(f"{word}: {sim:.3f}")

#     #     # Compare with baseline
#     #     jaccard_score = jaccard_similarity(baseline_neighbors, neighbors)
#     #     print(f"Jaccard Similarity with baseline: {jaccard_score:.3f}")
#     # else:
#     #     print(f"\nRun {i+1} | Settings: {setting} | '{keyword}' not in vocab")
# Out:
# Training Word2Vec model for phase_1...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 50
#      47 # Tokenize the preprocessed documents
#      48 tokenized_docs = [doc.split() for doc in docs]
# ---> 50 model = train_model(
#      51     tokenized_docs,
#      52     vector_size=setting['vector_size'],
#      53     window=setting['window'],
#      54     min_count=setting['min_count'],
#      55     epochs=setting['epochs'],
#      56     seed=42
#      57 )
#      59 # Save the model (in - memory)
#      60 model_dict[phase] = model
#
# Cell In[10], line 16, in train_model(tokenized_docs, vector_size, window, min_count, epochs, seed)
#      14 def train_model(tokenized_docs, vector_size, window, min_count, epochs, seed):
# ---> 16     model = Word2Vec(
#      17         sentences=tokenized_docs,
#      18         vector_size=vector_size, # embedding size
#      19         window=window, # context window size
#      20         min_count=min_count, # rare words
#      21         epochs=epochs, # training epochs
#      22         sg=1, # skip-gram
#      23         negative=5,
#      24         seed=seed, # for deterministic training
#      25         workers=1  # for deterministic training
#      26     )
#      27     return model
#
# File ~/miniconda3/envs/nlp/lib/python3.9/site-packages/gensim/models/word2vec.py:430, in Word2Vec.__init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab, shrink_windows)
#     428     self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=(epochs + 1))
#     429     self.build_vocab(corpus_iterable=corpus_iterable, corpus_file=corpus_file, trim_rule=trim_rule)
# --> 430     self.train(
#     431         corpus_iterable=corpus_iterable, corpus_file=corpus_file, total_examples=self.corpus_count,
#     432         total_words=self.corpus_total_words, epochs=self.epochs, start_alpha=self.alpha,
#     433         end_alpha=self.min_alpha, compute_loss=self.compute_loss, callbacks=callbacks)
#     434 else:
#     435     if trim_rule is not None:
#
# File ~/miniconda3/envs/nlp/lib/python3.9/site-packages/gensim/models/word2vec.py:1073, in Word2Vec.train(self, corpus_iterable, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1070     callback.on_epoch_begin(self)
#    1072 if corpus_iterable is not None:
# -> 1073     trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch(
#    1074         corpus_iterable, cur_epoch=cur_epoch, total_examples=total_examples,
#    1075         total_words=total_words, queue_factor=queue_factor, report_delay=report_delay,
#    1076         callbacks=callbacks, **kwargs)
#    1077 else:
#    1078     trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch_corpusfile(
#    1079         corpus_file, cur_epoch=cur_epoch, total_examples=total_examples, total_words=total_words,
#    1080         callbacks=callbacks, **kwargs)
#
# File ~/miniconda3/envs/nlp/lib/python3.9/site-packages/gensim/models/word2vec.py:1434, in Word2Vec._train_epoch(self, data_iterable, cur_epoch, total_examples, total_words, queue_factor, report_delay, callbacks)
#    1431     thread.daemon = True  # make interrupting the process with ctrl+c easier
#    1432     thread.start()
# -> 1434 trained_word_count, raw_word_count, job_tally = self._log_epoch_progress(
#    1435     progress_queue, job_queue, cur_epoch=cur_epoch, total_examples=total_examples,
#    1436     total_words=total_words, report_delay=report_delay, is_corpus_file_mode=False,
#    1437 )
#    1439 return trained_word_count, raw_word_count, job_tally
#
# File ~/miniconda3/envs/nlp/lib/python3.9/site-packages/gensim/models/word2vec.py:1289, in Word2Vec._log_epoch_progress(self, progress_queue, job_queue, cur_epoch, total_examples, total_words, report_delay, is_corpus_file_mode)
#    1286 unfinished_worker_count = self.workers
#    1288 while unfinished_worker_count > 0:
# -> 1289     report = progress_queue.get()  # blocks if workers too slow
#    1290     if report is None:  # a thread reporting that it finished
#    1291         unfinished_worker_count -= 1
#
# File ~/miniconda3/envs/nlp/lib/python3.9/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File ~/miniconda3/envs/nlp/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:
